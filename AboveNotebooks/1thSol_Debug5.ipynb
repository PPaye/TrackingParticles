# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from split import *
from score import *
from scipy import interpolate
import time 
# %matplotlib inline 
import warnings 
warnings.simplefilter('ignore', np.RankWarning)



"""
Title : Search_by_triplet Algorthm. Code Implementation on PYTHON.
Autor : Piter A. Paye M. 

Description: 

The next algorithm is inspired on the work of Daniel Campora, with the exception of paralelization.
Also, it includes ideas of Misha. 

Search_by_triplet is an algorithm employed actually on the velo Detector. with an efficieny of.

The heart of the algorithm is 



Changes from the first version: 
1. Squeletum of the algorithm. 
2. First Tracks
3. I do not remeber
4. 
5. 
6. 
7. Adding Time to the algorithm


"""
# Out:
# '\nTitle : Search_by_triplet Algorthm. Code Implementation on PYTHON.\nAutor : Piter A. Paye M. \n\nDescription: \n\nThe next algorithm is inspired on the work of Daniel Campora, with the exception of paralelization.\nAlso, it includes ideas of Misha. \n\nSearch_by_triplet is an algorithm employed actually on the velo Detector. with an efficieny of.\n\nThe heart of the algorithm is \n\n\n\nChanges from the first version: \n1. Squeletum of the algorithm. \n2. First Tracks\n3. I do not remeber\n4. \n5. \n6. \n7. Adding Time to the algorithm\n\n\n'

# %%
# Ba
def rho(x,y):
    return np.sqrt(x*x + y*y)
def r(x,y,z):
    return np.sqrt(x*x + y*y + z*z)
def theta(x,y,z):
    return np.arccos(z/r(x,y,z))
def phi(x,y):
    return np.arctan(y/x)
def module(r):
    return np.sqrt(np.sum(r*r))
def r_e(z, r_l, r_c):
    z_c = r_c[2] 
    r_versor = (r_l - r_c)/module(r_l - r_c)               # computing r_versor
    r_versor_dot_z_versor = r_versor[2]  
    return r_c - r_versor/r_versor_dot_z_versor*(z_c - z)  # IMPORTANT WITH THE MINUS SIGN.

# %%
def reading_data(fraction):
    name = 'data/RAMPData55microns50psInner200microns50psOuter_train.txt' # To be modified for others. 
    data_fraction = fraction
    
    df = pd.DataFrame()
    df = pd.read_csv(name, sep=' ') # All data.
    df,_ = Split_frac(df, data_fraction)
    return df

# %%
# DATAFRAME will be a global data. 
fraction = 0.004 
dphi     = 0.01                      
df_original = reading_data(fraction)  
df          = df_original        
df_search   = df_original

# %%
def sortbyphi(df):
    '''Description:
    Sort each D_i increasingly accoording to phi
    '''
    z = np.sort(df['z'].unique())
    df['phi'] = np.arctan(df['x']/df['y']) 
    modules = [] 
    for layer_i in z[::-1] :
        tmp = df.query(f'z=={layer_i}')

        tmp = tmp.sort_values('phi', ascending=True)

        tmp['used'] = False
        #
        modules.append(tmp)
    return modules

# %%
def findcandidatewindows(left_mod, mod, right_mod, dphi):
    '''Description: 
        Compute the first and last candidates(the window) according to acceptance range(dphi) for each hit.
        SUPPOSSING THAT ALL DATA ARE ORDERED ACCOURDING TO PHI. THIS PROCCESS WAS DONE Previously
        In case of add more information to the modules, one easily can add throught the iteration 
    '''
    
    right_hit_max = [] 
    right_hit_min = [] 

    for phi_i in mod['phi'] :  
        down      = phi_i - dphi 
        up        = phi_i + dphi 
        condition = f'{down} <= phi <=  {up}'
        tmp_df    = right_mod.query(condition)
    

        if not tmp_df.empty:
            m = tmp_df['hit_id'][tmp_df.index[0]]    # minumum hit 
            M = tmp_df['hit_id'][tmp_df.index[-1]]   # maximum hit 
            right_hit_min.append(m) 
            right_hit_max.append(M) 
        elif tmp_df.empty :
            m = "nan" #pd.np.nan                     # minumum hit 
            M = "nan" #pd.np.nan                     # maximum hit
            right_hit_min.append(m)  
            right_hit_max.append(M) 

            
    left_hit_max = [] 
    left_hit_min = [] 
    for phi_i in mod['phi']:  
        down      = phi_i - dphi 
        up        = phi_i + dphi 
        condition = f'{down} <= phi <= {up}'
        tmp_df = left_mod.query(condition)
        if not tmp_df.empty :
            m = tmp_df['hit_id'][tmp_df.index[0]]        # minumum hit 
            M = tmp_df['hit_id'][tmp_df.index[-1]]       # maximum hit  
            left_hit_min.append(m)
            left_hit_max.append(M)
        elif tmp_df.empty :
            #print("data_frame is empty LEFT")
            m = "nan"               # minumum hit 
            M = "nan"               # maximum hit
            left_hit_min.append(m) 
            left_hit_max.append(M) 

    mod["right_hit_max"] = right_hit_max  
    mod["right_hit_min"] = right_hit_min  
    
    mod["left_hit_max"]  = left_hit_max   
    mod["left_hit_min"]  = left_hit_min   
    
   
    return mod

# %%
def trackseeding():
    global left_mod, mod, right_mod

    '''Description: 
        Checks the preceding and following modules for compatible hits using the above results.
        
        All triplets in the search window are fitted and compared.
        
        and the best one is kept as a track seed.
        
        stores its best found triplet
        Finding triplets is ap- plied in first instance to the modules
        that are further apart from the collision point
        Each triplet is the seed of a forming track
    '''
    def fit(triplet): 
        phi_data = [ df.query(f'hit_id == {hit}')['phi'] for hit in triplet ]
        z_data   = [ df.query(f'hit_id == {hit}')['z'] for hit in triplet   ]
        phi_data = [ hit.values[0] for hit in phi_data                      ]                        
        z_data   = [ hit.values[0] for hit in z_data                        ]                    

        fitting = np.polyfit(phi_data, z_data, 1)

        chiSquared = np.sum((np.polyval(fitting, z_data) - phi_data)**2) 
        return chiSquared 
    
        
    df_triplets = [] 
    for index, part in mod.iterrows():

        r_hit_max, r_hit_min = part["right_hit_max"], part["right_hit_min"]  
        l_hit_max, l_hit_min = part["left_hit_max"],  part["left_hit_min" ] 
        
        if r_hit_max is "nan":
            print(r_hit_max)
            print("pass NAN 1")
            continue 
            #print("pass NAN 1, then")
        if r_hit_min is "nan":
            print(r_hit_min)
            print("pass NAN 2")
            continue 
            #print("pass NAN 2")
        if l_hit_max is "nan":
            print(l_hit_max)
            print("pass NAN 3")
            continue 
            #print("pass NAN 2")
        if l_hit_min is "nan":
            print(l_hit_min)
            print("pass NAN 4")
            continue 
            #print("pass NAN 2") 
        
        r_phi_max = right_mod.query(f"hit_id == {r_hit_max}")['phi'].values[0]
        r_phi_min = right_mod.query(f"hit_id == {r_hit_min}")['phi'].values[0] 
        
        l_phi_max = left_mod.query(f"hit_id == {l_hit_max}")['phi'].values[0]  
        l_phi_min = left_mod.query(f"hit_id == {l_hit_min}")['phi'].values[0]  
        
        left_mod.query(f" {l_phi_min} <= phi <= {l_phi_max}")
        
        tmp_right = right_mod.query(f" {r_phi_min} <= phi <= {r_phi_max} & used == False  ")

        for R in tmp_right['phi'].values:
            tmp_left = left_mod.query(f" {l_phi_min} <= phi <= {l_phi_max} & used == False ")
            for L in tmp_left['phi'].values: 
                
                hit_center = int(part["hit_id"])  
                hit_left   = int(tmp_left.query(f" phi == {L}")['hit_id'].values[0] )    
                hit_right  = int(tmp_right.query(f" phi == {R}")['hit_id'].values[0] )                          

                triplets = [hit_left, hit_center, hit_right]
                chi2 = fit(triplets)                                                                                                                                                                

                df_triplets.append(list(triplets)+[chi2])
    df_triplets = pd.DataFrame(df_triplets, columns = ['left_hit', 'hit', 'right_hit', 'chi2']) 

              
    def best_choice(df_triplets):
        seeds = []
        for hit_c in df_triplets['hit'].values :
            tmp = df_triplets.query(f'hit == {hit_c}')
            minimum = (tmp['chi2']).idxmin()
            t = (tmp.loc[minimum]).values 
            t = [int(i) for i in t]
            ######################MARKING TRIPLES###########
            # MARKING EACH HIT AS USED ON THE WORKING MODULE  # LEFT
            hit_id_left = t[0] 
            index_left   = df.query(f"hit_id == {hit_id_left}").index[0]   #################### df works but it would be best to use
            left_mod.loc[index_left, "used"] = True    #MARKING USED VALUE
            ################################################  # CENTER
            # MARKING EACH HIT AS USED ON THE WORKING MODULE 
            hit_id_center = t[1] 
            index_center = df.query(f"hit_id == {hit_id_center}").index[0]
            mod.loc[index_center, "used"] = True       #MARKING USED VALUE
            ################################################  # RIGHT
            # MARKING EACH HIT AS USED ON THE WORKING MODULE
            hit_id_right = t[2] 
            index_right  = df.query(f"hit_id == {hit_id_right}").index[0]
            right_mod.loc[index_right, "used"] = True  #MARKING USED VALUE
            seeds.append(list(t[:3]))    
        return seeds 
    
    seeds = best_choice(df_triplets)
    return seeds

# %%
def track_forwarding():
    global tracks, work_module, dphi # this step is important, because I'am using the values of work_module at the same time to modify.
    new_tracks = []
    #Notation:
    # x0, y0, z0 is the EXTRAPOLATED track.               
    # X,  Y,  Z  is the last track on previous module.   
    # x,  y,  z  is the tracks on a window.                                                                 
    #Searching tracks on phi_e - dphi < phi < d that minimize the extrapolated function.
    #r0 = np.array([x0, y0, z0] )
    #r  = np.array([x, y, 1] )
    #R  = np.array([X,  Y,  Z ] )
    def mod(r):
        return np.sqrt(np.sum(r*r))
    def ext_func(r0, r1, r):
        # r0, r1, r are arrays
        dx2_plus_dy2 = mod(r0-r)  # distance between hits on the working module.
        dz2          = mod(r1-r0) # distance between the last two modules.                              
        return dx2_plus_dy2/dz2   

    z_e = float(work_module['z'].unique()) #z_position of work_module

    for track in tracks: 
        data = []    
        vector_data = []
        for hit in track[0:2] : 
            data.append(tuple((df.query(f'hit_id == {hit}')[['phi', 'z']]).values[0]))     
            vector_data.append(tuple((df.query(f'hit_id == {hit}')[['x', 'y', 'z']]).values[0]))  
        
        phi_data, z_data = zip(*data)

        ext_seg = interpolate.interp1d(z_data, phi_data, fill_value = "extrapolate" )
        phi_e = ext_seg(z_e)
        
        r_l, r_c = vector_data 
        r_l, r_c = np.array(r_l), np.array(r_c)
        
        x_e, y_e, z_e = r_e(z_e, r_l, r_c)
        
        phi_a = phi_e - dphi
        phi_b = phi_e + dphi 
        
        df_work_module_window = work_module.query(f" {phi_a} <= phi <= {phi_b} " ) 
        
        hit_left = track[0]   
        R  = df.query(f'hit_id == {hit_left}')[['x','y','z']].values[0] 
        r0 = np.array([x_e, y_e ,z_e ])
        
        tmp_candidates = []
        for index, row in df.iterrows(): 
            r      =  row[['x', 'y', 'z']].values 
            hit_id =  row['hit_id']    

            ext_func_value = ext_func(r0, R, r)
            tmp_candidates.append( [hit_id, ext_func_value] )

        
        if tmp_candidates == []:                                            
            print("an error ocurred: with tmp_candidates is empty ")                                          
            break                                                                                              

        df_candidates = pd.DataFrame(tmp_candidates, columns=["hit_id", "ext_fun"])

        index      = df_candidates['ext_fun'].idxmin()

        new_hit_id = df_candidates['hit_id'][index]
        new_hit_id = int(new_hit_id)

        work_module.loc[index, "used"] = True 
        new_track  = [new_hit_id] + track

        new_tracks.append(new_track)                    
    return new_tracks

# %% [markdown]
# # MAIN

# %%
########################################################################################
################################# MAIN #################################################
########################################################################################
############################ GENERAL ALGORITHM #########################################



#####PARAMETERS#####
fraction = 0.004    
dphi     = 0.01  
m        = 22  # number of modules counted from the left.
               # from 1 to 24. No more. 
    
new_tracks = []                      # 
df = reading_data(fraction)          # where data is unmodified.
# df_search   = df_original          # where I am searching 
tracks = []                          # [[1,24, 5], [7,6,4] ,[346,7,32,], ... ]
# *********************IMPORTANT**********************************************
# The information of tracks is ordered. 
# Because each of its elements are an ordered list according to module layers.
# However, the information of hits are unique and not matter if are a ordered set. 
# But it was filled out in order

# SEPARATION BY MODULE
modules = sortbyphi(df)     # I will delete the information in this place. Because I can, now, modified the values of the modules. 
                            # Defined Below 


####################################################################################
###############################ITERATION OVER MODULES###############################
####################################################################################



for M_i in range(len(modules)-1, len(modules)-m-1, -1):
    t1 = time.time()
    print(f"module number {M_i}")
    M_i = M_i - 1

    left_mod  =  modules[M_i - 1]  
    mod       =  modules[M_i    ]  
    right_mod =  modules[M_i + 1]          

    mod       = findcandidatewindows(left_mod, mod, right_mod, dphi)

    new_seeds = trackseeding()     
    
    tracks      = tracks + new_seeds  
    
    work_module = modules[M_i - 2]  

    new_tracks = track_forwarding()  
    
    t2 = time.time()

    print("time per module", t2-t1) 

tracks = pd.Series(new_tracks)

print(" FINDING TRACKS FINISHED ")

######################
######  FINALLY  #####
###### COMPARING #####
######################
df_real_tracks = df.groupby(['particle_id'])['hit_id'].unique() 
#Scoring(df_real_tracks, tracks)
######################
# Out:
# module number 24
# nan
# pass NAN 1
# time per module 5.4708380699157715
# module number 23
# time per module 4.88697361946106
# module number 22
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     180             if self.has_resolvers:
# --> 181                 return self.resolvers[key]
#     182
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/collections/__init__.py in __getitem__(self, key)
#     913                 pass
# --> 914         return self.__missing__(key)            # support subclasses that define __missing__
#     915
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/collections/__init__.py in __missing__(self, key)
#     905     def __missing__(self, key):
# --> 906         raise KeyError(key)
#     907
#
# KeyError: 'nan'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     191                 # e.g., df[df > 0]
# --> 192                 return self.temps[key]
#     193             except KeyError:
#
# KeyError: 'nan'
#
# During handling of the above exception, another exception occurred:
#
# UndefinedVariableError                    Traceback (most recent call last)
# <ipython-input-9-f0d89e23c773> in <module>
#      42     right_mod =  modules[M_i + 1]
#      43
# ---> 44     mod       = findcandidatewindows(left_mod, mod, right_mod, dphi)
#      45
#      46     new_seeds = trackseeding()
#
# <ipython-input-6-d404506f87fa> in findcandidatewindows(left_mod, mod, right_mod, dphi)
#      13         up        = phi_i + dphi
#      14         condition = f'{down} <= phi <=  {up}'
# ---> 15         tmp_df    = right_mod.query(condition)
#      16
#      17
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    3086         kwargs['level'] = kwargs.pop('level', 0) + 1
#    3087         kwargs['target'] = None
# -> 3088         res = self.eval(expr, **kwargs)
#    3089
#    3090         try:
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    3201             kwargs['target'] = self
#    3202         kwargs['resolvers'] = kwargs.get('resolvers', ()) + tuple(resolvers)
# -> 3203         return _eval(expr, inplace=inplace, **kwargs)
#    3204
#    3205     def select_dtypes(self, include=None, exclude=None):
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     292
#     293         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env,
# --> 294                            truediv=truediv)
#     295
#     296         # construct the engine and evaluate the parsed expression
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/expr.py in __init__(self, expr, engine, parser, env, truediv, level)
#     747         self.env.scope['truediv'] = truediv
#     748         self._visitor = _parsers[parser](self.env, self.engine, self.parser)
# --> 749         self.terms = self.parse()
#     750
#     751     @property
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/expr.py in parse(self)
#     764     def parse(self):
#     765         """Parse an expression"""
# --> 766         return self._visitor.visit(self.expr)
#     767
#     768     @property
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     329         method = 'visit_' + node.__class__.__name__
#     330         visitor = getattr(self, method)
# --> 331         return visitor(node, **kwargs)
#     332
#     333     def visit_Module(self, node, **kwargs):
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit_Module(self, node, **kwargs)
#     335             raise SyntaxError('only a single expression is allowed')
#     336         expr = node.body[0]
# --> 337         return self.visit(expr, **kwargs)
#     338
#     339     def visit_Expr(self, node, **kwargs):
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     329         method = 'visit_' + node.__class__.__name__
#     330         visitor = getattr(self, method)
# --> 331         return visitor(node, **kwargs)
#     332
#     333     def visit_Module(self, node, **kwargs):
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit_Expr(self, node, **kwargs)
#     338
#     339     def visit_Expr(self, node, **kwargs):
# --> 340         return self.visit(node.value, **kwargs)
#     341
#     342     def _rewrite_membership_op(self, node, left, right):
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     329         method = 'visit_' + node.__class__.__name__
#     330         visitor = getattr(self, method)
# --> 331         return visitor(node, **kwargs)
#     332
#     333     def visit_Module(self, node, **kwargs):
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit_Compare(self, node, **kwargs)
#     671         for op, comp in zip(ops, comps):
#     672             new_node = self.visit(ast.Compare(comparators=[comp], left=left,
# --> 673                                               ops=[self.translate_In(op)]))
#     674             left = comp
#     675             values.append(new_node)
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     329         method = 'visit_' + node.__class__.__name__
#     330         visitor = getattr(self, method)
# --> 331         return visitor(node, **kwargs)
#     332
#     333     def visit_Module(self, node, **kwargs):
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit_Compare(self, node, **kwargs)
#     664             op = self.translate_In(ops[0])
#     665             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 666             return self.visit(binop)
#     667
#     668         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     329         method = 'visit_' + node.__class__.__name__
#     330         visitor = getattr(self, method)
# --> 331         return visitor(node, **kwargs)
#     332
#     333     def visit_Module(self, node, **kwargs):
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit_BinOp(self, node, **kwargs)
#     433
#     434     def visit_BinOp(self, node, **kwargs):
# --> 435         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     436         left, right = self._maybe_downcast_constants(left, right)
#     437         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     370     def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     371         if left is None:
# --> 372             left = self.visit(node.left, side='left')
#     373         if right is None:
#     374             right = self.visit(node.right, side='right')
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     329         method = 'visit_' + node.__class__.__name__
#     330         visitor = getattr(self, method)
# --> 331         return visitor(node, **kwargs)
#     332
#     333     def visit_Module(self, node, **kwargs):
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit_Name(self, node, **kwargs)
#     447
#     448     def visit_Name(self, node, **kwargs):
# --> 449         return self.term_type(node.id, self.env, **kwargs)
#     450
#     451     def visit_NameConstant(self, node, **kwargs):
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/ops.py in __init__(self, name, env, side, encoding)
#      62         self.is_local = (tname.startswith(_LOCAL_TAG) or
#      63                          tname in _DEFAULT_GLOBALS)
# ---> 64         self._value = self._resolve_name()
#      65         self.encoding = encoding
#      66
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/ops.py in _resolve_name(self)
#      79
#      80     def _resolve_name(self):
# ---> 81         res = self.env.resolve(self.local_name, is_local=self.is_local)
#      82         self.update(res)
#      83
#
# /afs/cern.ch/work/p/ppayemam/miniconda/envs/ramp_velo_challenge/lib/python3.7/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     192                 return self.temps[key]
#     193             except KeyError:
# --> 194                 raise compu.ops.UndefinedVariableError(key, is_local)
#     195
#     196     def swapkey(self, old_key, new_key, new_value=None):
#
# UndefinedVariableError: name 'nan' is not defined
